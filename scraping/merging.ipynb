# %%
import pandas as pd

# %%
data_1=pd.read_excel("TPE_news_10000_12176.xlsx")
data_1=data_1[data_1["Unnamed: 0"]<12000]
data_1
# Out:
#       Unnamed: 0                                                url  \
# 0          10000  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1          10001  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 2          10002  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 3          10003  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 4          10004  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# ...          ...                                                ...
# 1995       11995  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1996       11996  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1997       11997  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1998       11998  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1999       11999  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
#
#                                                   title  \
# 0                                   騎車未扣安全帽扣 內湖警盤查竟是通緝犯
# ...

# %%
data_2=pd.read_excel("TPE_news_12000_13000.xlsx")
data_2
# Out:
#      Unnamed: 0                                                url  \
# 0         12000  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1         12001  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 2         12002  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 3         12003  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 4         12004  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# ..          ...                                                ...
# 995       12995  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 996       12996  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 997       12997  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 998       12998  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 999       12999  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
#
#                                   title  \
# 0                       本土猛禽大冠鷲-保育大使培訓中
# 1                    ​文山警召開校安座談會 傾聽家長心聲
# ...

# %%
data_3=pd.read_excel("TPE_news_13000_15000.xlsx")
data_3
# Out:
#       Unnamed: 0                                                url  \
# 0          13000  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1          13001  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 2          13002  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 3          13003  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 4          13004  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# ...          ...                                                ...
# 1995       14995  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1996       14996  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1997       14997  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1998       14998  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1999       14999  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
#
#                                               title  \
# 0                                      中秋吃柚  您『藥』小心
# ...

# %%
data_4=pd.read_excel("TPE_news_15000_17000.xlsx")
data_4
# Out:
#       Unnamed: 0                                                url  \
# 0          15000  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1          15001  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 2          15002  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 3          15003  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 4          15004  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# ...          ...                                                ...
# 1995       16995  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1996       16996  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1997       16997  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1998       16998  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1999       16999  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
#
#                                            title  \
# 0          事後新聞稿1100424 再興小學-小小的閱讀之火，泛起大大的閱讀分享漣漪
# ...

# %%
temp=pd.concat([data_1,data_2,data_3,data_4]).reset_index()
temp
# Out:
#       index  Unnamed: 0                                                url  \
# 0         0       10000  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 1         1       10001  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 2         2       10002  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 3         3       10003  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 4         4       10004  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# ...     ...         ...                                                ...
# 6995   1995       16995  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 6996   1996       16996  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 6997   1997       16997  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 6998   1998       16998  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
# 6999   1999       16999  News_Content.aspx?n=F0DDAF49B89E9413&sms=72544...
#
#                                                   title  \
# ...

# %%
temp.to_excel('TPE_news_10000_17000.xlsx',engine='xlsxwriter')
